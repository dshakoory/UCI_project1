# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
BLS_data = pd.read_csv("BLS_data_2018.csv")
BLS_data.head()
# Out:
#    area  year area_title  area_type naics     naics_title  own_code occ_code  \
# 0    99  2018       U.S.          1     0  Cross-industry      1235  00-0000
# 1    99  2018       U.S.          1     0  Cross-industry      1235  11-0000
# 2    99  2018       U.S.          1     0  Cross-industry      1235  11-1000
# 3    99  2018       U.S.          1     0  Cross-industry      1235  11-1010
# 4    99  2018       U.S.          1     0  Cross-industry      1235  11-1011
#
#                 occ_title   o_group  ... h_median h_pct75 h_pct90 a_pct10  \
# 0         All Occupations     total  ...    18.58   30.06   47.31  20,690
# 1  Management Occupations     major  ...    50.11   72.93       #  49,260
# 2          Top Executives     minor  ...    49.73   78.81       #  43,400
# 3        Chief Executives     broad  ...    91.15       #       #  68,360
# 4        Chief Executives  detailed  ...    91.15       #       #  68,360
#
#    a_pct25 a_median  a_pct75 a_pct90 annual hourly
# 0   25,740   38,640   62,510  98,410    NaN    NaN
# 1   70,880  104,240  151,700       #    NaN    NaN
# 2   66,000  103,450  163,930       #    NaN    NaN
# 3  115,960  189,600        #       #    NaN    NaN
# 4  115,960  189,600        #       #    NaN    NaN
#
# [5 rows x 30 columns]

# %%
US_data = BLS_data[BLS_data["area_type"] == 1]
US_data.drop(["own_code","annual", "occ_code","hourly", "area_type", "area", "naics", "naics_title"], axis = 1, inplace=True)
US_data.dropna(axis=1, inplace=True)

State_data = BLS_data[( BLS_data["area_type"] == 2) & ( BLS_data["area_title"] != "District of Columbia")]
State_data.drop(["own_code","annual", "occ_code","hourly", "area_type", "area", "naics", "naics_title"], axis = 1, inplace=True)
State_data.dropna(axis=1, inplace=True)

US_data.head()
State_data.head()
# Out:
#         year  area_title        occ_title o_group     tot_emp emp_prse  \
# 175951  2018     Alabama  All Occupations   total   1,943,760      0.4
# 175952  2018      Alaska  All Occupations   total     315,250      0.8
# 175953  2018     Arizona  All Occupations   total   2,789,520      0.5
# 175954  2018    Arkansas  All Occupations   total   1,210,120      0.6
# 175955  2018  California  All Occupations   total  17,007,690      0.2
#
#        jobs_1000 loc_quotient h_mean  a_mean  ... h_pct10 h_pct25 h_median  \
# 175951      1000            1  21.05  43,790  ...    8.67   10.77    16.22
# 175952      1000            1  28.22  58,710  ...   11.62    15.4    23.09
# 175953      1000            1   23.7  49,290  ...    10.8   12.21     17.8
# 175954      1000            1  19.97  41,540  ...    9.19   10.75    15.31
# 175955      1000            1  28.44  59,150  ...   11.34   13.38     20.4
#
#        h_pct75 h_pct90 a_pct10 a_pct25 a_median a_pct75  a_pct90
# 175951   25.63   38.28  18,030  22,400   33,740  53,310   79,630
# 175952   35.32   49.56  24,180  32,020   48,020  73,460  103,080
# 175953    28.2   43.62  22,470  25,410   37,020  58,660   90,730
# 175954   23.62   35.25  19,110  22,360   31,850  49,140   73,310
# 175955   35.15   56.54  23,590  27,830   42,430  73,110  117,590
#
# [5 rows x 21 columns]

# %%
US_data_avg = US_data[US_data["o_group"] == "major"]
US_data_avg .drop_duplicates(["occ_title"], keep="first", inplace=True) 
US_data_avg ['a_mean'] = US_data_avg ['a_mean'].str.replace(',', '')  #remove comma in numbers
US_data_avg ['a_mean'] = US_data_avg ['a_mean'].str.replace('*', '0')
US_data_avg ['a_mean'] = US_data_avg ['a_mean'].astype(int)           #convert string to integers
US_data_avg .sort_values("a_mean", ascending = False, inplace=True)
US_data_avg [["occ_title", "a_mean"]].head(10)
# Out:
#                                              occ_title  a_mean
# 1                               Management Occupations  121560
# 315                                  Legal Occupations  108690
# 126              Computer and Mathematical Occupations   91530
# 158           Architecture and Engineering Occupations   87370
# 489  Healthcare Practitioners and Technical Occupat...   82000
# 70       Business and Financial Operations Occupations   76910
# 218     Life, Physical, and Social Science Occupations   76160
# 427  Arts, Design, Entertainment, Sports, and Media...   59780
# 331       Education, Training, and Library Occupations   56620
# 939            Construction and Extraction Occupations   51220

# %%
State_employment_rate = State_data[State_data["o_group"] == "total"]
State_employment_rate["tot_emp"] = State_employment_rate['tot_emp'].str.replace(',', '')  #remove comma in numbers
State_employment_rate["tot_emp"] = State_employment_rate["tot_emp"].astype(int)  
State_employment_rate.sort_values("tot_emp", ascending=False, inplace=True)
State_employment_rate[["area_title", "tot_emp"]].head()
# Out:
#         area_title   tot_emp
# 175955  California  17007690
# 175994       Texas  12113810
# 175983    New York   9385620
# 175960     Florida   8608660
# 175964    Illinois   5991270

# %%
#State Average Annual Income 2018
State_avg_income= State_data[State_data["o_group"] == "total"]
State_avg_income["a_mean"] = State_avg_income['a_mean'].str.replace(',', '')  #remove comma in numbers
State_avg_income["a_mean"] = State_avg_income["a_mean"].astype(int)     
State_avg_income.sort_values("a_mean", ascending=False, inplace=True)
State_avg_income[["area_title", "a_mean"]].head(10)
# Out:
#            area_title  a_mean
# 175972  Massachusetts   63910
# 175983       New York   61870
# 175957    Connecticut   60780
# 175998     Washington   59410
# 175955     California   59150
# 175971       Maryland   58770
# 175952         Alaska   58710
# 175981     New Jersey   58210
# 175956       Colorado   55820
# 175997       Virginia   55310
